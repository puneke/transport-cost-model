# %%
from pathlib import Path

import pandas as pd

# %%
df = pd.read_excel('data/output/for_manual_input.xlsx')
df

# %% [markdown]
# Cost based on mapbox distances.

# %%
diesel_price_per_litre = 1.78
fuel_consumption_per_100km = 20
cost_per_km = diesel_price_per_litre * (fuel_consumption_per_100km / 100)

df['Cost'] = round(df['Distance (mapbox)'] * cost_per_km, 2) 

df
